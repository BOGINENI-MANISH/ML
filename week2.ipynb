# %%
import numpy as np

x=np.array([1000,1200,1300,1400,1600])
y=np.array([200000,250000,280000,300000,350000])

N=len(x)

x_mean=np.mean(x)
y_mean=np.mean(y)
xy_mean=np.mean(x*y)
x_square_mean=np.mean(x**2)
b1=(xy_mean-x_mean*y_mean)/(x_square_mean-x_mean**2)
b0=y_mean-b1*x_mean

def predict(x):
    return b0+b1*x

print("the predicted price for a house with square footage of 1500 is: ",predict(1500))
# Out:
# the predicted price for a house with square footage of 1500 is:  326000.0

# %%
import numpy as np

x=np.array([2012,2013,2014,2015,2016,2017,2018,2019,2020,2021])
y=np.array([9750000,9980000,10230000,10150000,10180000,10350000,10590000,10740000,9530000,10580000])

N=len(x)

x_mean=np.mean(x)
y_mean=np.mean(y)
xy_mean=np.mean(x*y)
x_square_mean=np.mean(x**2)
b1=(xy_mean-x_mean*y_mean)/(x_square_mean-x_mean**2)
b0=y_mean-b1*x_mean

def predict(x):
    return b0+b1*x
x=round(predict(2898))
print("the predicted price for a house with square footage of  is: ",x)
# Out:
# the predicted price for a house with square footage of 2898AD is:  54870667
